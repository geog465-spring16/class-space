# %%
import csv

# %%
# uses the main file as an input
my_file = open('C:\Users\Travis\Desktop\Hwk2\Code_Violation_Cases.csv','r')

# %%
# establish a new dictionary reader 
cases = csv.DictReader(my_file, delimiter = ',')

# %%
# establish a new table for cases and numbers
table_cases = open('C:\Users\Travis\Desktop\Hwk2\cases.csv','w')
columns = ['id', 'number']
table_cases_dwriter = csv.DictWriter(table_cases, fieldnames = columns)
table_cases_dwriter.writeheader()
table_cases_dreader = csv.DictReader(open('C:\Users\Travis\Desktop\Hwk2\Code_Violation_Cases.csv','r'))

# %%
# create rows with cases and numbers
rows = []
count = 1
for row in table_cases_dreader:
    row_dictionary = {'id': count, 'number': row['Case Number']}
    rows.append(row_dictionary)
    count += 1
table_cases_dwriter.writerows(rows)
table_cases.close()

# %%
# opens and prints the results
table_cases = open('C:\Users\Travis\Desktop\Hwk2\cases.csv')
c_dreader = csv.DictReader(table_cases)
for c in range(0, len(rows)):
    print c_dreader.next()
# Out:
# {'id': '1', 'number': '1037401'}
# {'id': '2', 'number': '1037400'}
# {'id': '3', 'number': '1037399'}
# {'id': '4', 'number': '1037398'}
# {'id': '5', 'number': '1037397'}
# {'id': '6', 'number': '1037396'}
# {'id': '7', 'number': '1037395'}
# {'id': '8', 'number': '1037394'}
# {'id': '9', 'number': '1037394'}
# {'id': '10', 'number': '1037393'}
# {'id': '11', 'number': '1037392'}
# {'id': '12', 'number': '1037391'}
# {'id': '13', 'number': '1037390'}
# {'id': '14', 'number': '1037389'}
# {'id': '15', 'number': '1037388'}
# {'id': '16', 'number': '1037387'}
# {'id': '17', 'number': '1037386'}
# {'id': '18', 'number': '1037385'}
# {'id': '19', 'number': '1037367'}
# {'id': '20', 'number': '1037384'}
# {'id': '21', 'number': '1037383'}
# {'id': '22', 'number': '1037382'}
# {'id': '23', 'number': '1037381'}
# {'id': '24', 'number': '1037380'}
# {'id': '25', 'number': '1037379'}
# {'id': '26', 'number': '1037378'}
# {'id': '27', 'number': '1037377'}
# {'id': '28', 'number': '1037376'}
# ...

# %%
# similar thing as before - establishes a new table
table_case_type = open('C:\Users\Travis\Desktop\Hwk2\case_types.csv','w')
columns = ['id', 'case_type']
table_case_type_dwriter = csv.DictWriter(table_case_type, fieldnames = columns)
table_case_type_dwriter.writeheader()
table_case_type_dreader = csv.DictReader(open('C:\Users\Travis\Desktop\Hwk2\Code_Violation_Cases.csv','r'))

# %%
# recreate rows with new information
rows = []
count = 1
for row in table_case_type_dreader:
    rowD = {'id': count, 'case_type': row['Case Type']}
    rows.append(rowD)
    count += 1
table_case_type_dwriter.writerows(rows)
table_case_type.close()

# %%
# opens the table to read and print 
case_type_table = open('C:\Users\Travis\Desktop\Hwk2\case_types.csv')
case_type_dreader = csv.DictReader(case_type_table)

# %%
# prints the new rows
for c in range(0,len(rows)):
    print case_type_dreader.next()
# Out:
# {'case_type': 'CONSTRUCTION', 'id': '1'}
# {'case_type': 'CITATION', 'id': '2'}
# {'case_type': 'TENANT RELOCATION ORDINANCE', 'id': '3'}
# {'case_type': 'HOUSING / ZONING', 'id': '4'}
# {'case_type': 'CITATION', 'id': '5'}
# {'case_type': 'HOUSING / ZONING', 'id': '6'}
# {'case_type': 'CONSTRUCTION', 'id': '7'}
# {'case_type': 'CITATION', 'id': '8'}
# {'case_type': 'CITATION', 'id': '9'}
# {'case_type': 'HOUSING / ZONING', 'id': '10'}
# {'case_type': 'HOUSING / ZONING', 'id': '11'}
# {'case_type': 'CONSTRUCTION', 'id': '12'}
# {'case_type': 'CITATION', 'id': '13'}
# {'case_type': 'CITATION', 'id': '14'}
# {'case_type': 'CITATION', 'id': '15'}
# {'case_type': 'HOUSING / ZONING', 'id': '16'}
# {'case_type': 'HOUSING / ZONING', 'id': '17'}
# {'case_type': 'TENANT RELOCATION ORDINANCE', 'id': '18'}
# {'case_type': 'CITATION', 'id': '19'}
# {'case_type': 'CITATION', 'id': '20'}
# {'case_type': 'CITATION', 'id': '21'}
# {'case_type': 'CITATION', 'id': '22'}
# ...

# %%
# creates a new table file for addressses
address_table = open('C:\Users\Travis\Desktop\Hwk2\case_address.csv','w')

# %%
# establish a new table
columns = ['id', 'address']
address_table_dwriter = csv.DictWriter(address_table, fieldnames = columns)
address_table_dwriter.writeheader()
address_table_dreader = csv.DictReader(open('C:\Users\Travis\Desktop\Hwk2\Code_Violation_Cases.csv','r'))

# %%
# recreate rows with addresses
rows = []
count = 1
for row in address_table_dreader:
    rowD = {'id': count, 'address': row['Address']}
    rows.append(rowD)
    count += 1
address_table_dwriter.writerows(rows)
address_table.close()

# %%
# opnes to read and print
address_table = open('C:\Users\Travis\Desktop\Hwk2\case_address.csv')
address_table_dreader = csv.DictReader(address_table)

# %%
for c in range(0,len(rows)):
    print address_table_dreader.next()

# %%
# simplified in a whole block of code for creating a table for Status
status_table = open('C:\Users\Travis\Desktop\Hwk2\status.csv','w')
columns = ['id', 'status']
status_table_dwriter = csv.DictWriter(status_table, fieldnames = columns)
status_table_dwriter.writeheader()
status_table_dreader = csv.DictReader(open('C:\Users\Travis\Desktop\Hwk2\Code_Violation_Cases.csv','r'))

rows = []
count = 1
for row in status_table_dreader:
    rowD = {'id': count, 'status': row['Status']}
    rows.append(rowD)
    count += 1
status_table_dwriter.writerows(rows)
status_table.close()

status_table = open('C:\Users\Travis\Desktop\Hwk2\status.csv')
status_table_dreader = csv.DictReader(status_table)

# %%
for c in range(0,len(rows)):
    print status_table_dreader.next()

# %%
# same thing - another block of codes for group table 
group_table = open('C:\Users\Travis\Desktop\Hwk2\group.csv','w')
columns = ['id', 'group']
group_table_dwriter = csv.DictWriter(group_table, fieldnames = columns)
group_table_dwriter.writeheader()
group_table_dreader = csv.DictReader(open('C:\Users\Travis\Desktop\Hwk2\Code_Violation_Cases.csv','r'))

rows = []
count = 1
for row in group_table_dreader:
    rowD = {'id': count, 'group': row['Case Group']}
    rows.append(rowD)
    count += 1
group_table_dwriter.writerows(rows)
group_table.close()

group_table = open('C:\Users\Travis\Desktop\Hwk2\group.csv')
group_table_dreader = csv.DictReader(group_table)

# %%
for c in range(0,len(rows)):
    print group_table_dreader.next()

# %%
# whole code to create a table for inspection date and results
inspection_table = open('C:\Users\Travis\Desktop\Hwk2\inspection.csv','w')
columns = ['id', 'date', 'result']
inspection_table_dwriter = csv.DictWriter(inspection_table, fieldnames = columns)
inspection_table_dwriter.writeheader()
inspection_table_dreader = csv.DictReader(open('C:\Users\Travis\Desktop\Hwk2\Code_Violation_Cases.csv','r'))

rows = []
count = 1
for row in inspection_table_dreader:
    rowD = {'id': count, 'date': row['Last Inspection Date'], 'result': row['Last Inspection Result']}
    rows.append(rowD)
    count += 1
inspection_table_dwriter.writerows(rows)
inspection_table.close()

inspection_table = open('C:\Users\Travis\Desktop\Hwk2\inspection.csv')
inspection_table_dreader = csv.DictReader(inspection_table)

# %%
for c in range(0,len(rowsSix)):
    print inspe_table_dreader.next()
    
# all done!
