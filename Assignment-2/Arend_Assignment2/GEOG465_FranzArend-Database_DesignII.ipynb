# %%
import csv

f = open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)

# %%
print row
# Out:
# ['CL77.031', 'URBAN SPACES II', '', '', 'Lake City Gateway', '', 'Sculpture', 'Concrete, wire, painted steel', '', '', 'Lake City Way NE', 'Lake City Way NE from 123rd NE to 127th NE', '47.71912', '-122.29557', 'Lake City Way NE from 123rd NE to 127th NE\nSeattle, WA\n(47.71912, -122.29557)', 'Michael Sweeney']

# %%
for row in my_csv:
    print row

# %%
import csv

f = open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'w')

for row in my_dreader:
        columnnames = ['id']

my_dwriter = csv.DictWriter(test_csv_2, fieldnames = columnnames)

my_dwriter.writeheader()

my_dwriter.writerow({'id': 'ESD00.074.02'})

test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader2:
    print row
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-e3d171a93b4a> in <module>()
#       8     my_dreader = csv.DictReader(f)
#       9
# ---> 10 test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'w')
#      11
#      12 for row in my_dreader:
#
# IOError: [Errno 22] invalid mode ('w') or filename: 'C:\\Users\\New Owner\\Desktop\test_csv_2.csv'

# %%
import csv

f = open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'w')

for row in my_dreader:
        columnnames = ['id']

my_dwriter = csv.DictWriter(test_csv_2, fieldnames = columnnames)

my_dwriter.writeheader()

my_dwriter.writerow({'id': 'ESD00.074.02'})

test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader2:
    print row
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-6-e3d171a93b4a> in <module>()
#       8     my_dreader = csv.DictReader(f)
#       9
# ---> 10 test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'w')
#      11
#      12 for row in my_dreader:
#
# IOError: [Errno 22] invalid mode ('w') or filename: 'C:\\Users\\New Owner\\Desktop\test_csv_2.csv'

# %%
import csv

f = open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('Users\New Owner\Desktop\test_csv_2.csv', 'w')

for row in my_dreader:
        columnnames = ['id']

my_dwriter = csv.DictWriter(test_csv_2, fieldnames = columnnames)

my_dwriter.writeheader()

my_dwriter.writerow({'id': 'ESD00.074.02'})

test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader2:
    print row
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-8-c3145dbb5d15> in <module>()
#       8     my_dreader = csv.DictReader(f)
#       9
# ---> 10 test_csv_2 = open('Users\New Owner\Desktop\test_csv_2.csv', 'w')
#      11
#      12 for row in my_dreader:
#
# IOError: [Errno 2] No such file or directory: 'Users\\New Owner\\Desktop\test_csv_2.csv'

# %%
import csv

f = open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'w')

for row in my_dreader:
        columnnames = ['id']

my_dwriter = csv.DictWriter(test_csv_2, fieldnames = columnnames)

my_dwriter.writeheader()

my_dwriter.writerow({'id': 'ESD00.074.02'})

test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader2:
    print row
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-9-e3d171a93b4a> in <module>()
#       8     my_dreader = csv.DictReader(f)
#       9
# ---> 10 test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'w')
#      11
#      12 for row in my_dreader:
#
# IOError: [Errno 22] invalid mode ('w') or filename: 'C:\\Users\\New Owner\\Desktop\test_csv_2.csv'

# %%
import csv

f = open('\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('\Users\New Owner\Desktop\test_csv_2.csv', 'w')

for row in my_dreader:
        columnnames = ['id']

my_dwriter = csv.DictWriter(test_csv_2, fieldnames = columnnames)

my_dwriter.writeheader()

my_dwriter.writerow({'id': 'ESD00.074.02'})

test_csv_2 = open('\Users\New Owner\Desktop\test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader2:
    print row
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-10-f6f9372795a0> in <module>()
#       8     my_dreader = csv.DictReader(f)
#       9
# ---> 10 test_csv_2 = open('\Users\New Owner\Desktop\test_csv_2.csv', 'w')
#      11
#      12 for row in my_dreader:
#
# IOError: [Errno 22] invalid mode ('w') or filename: '\\Users\\New Owner\\Desktop\test_csv_2.csv'

# %%
import csv

f = open('Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('Users\New Owner\Desktop\test_csv_2.csv', 'w')

for row in my_dreader:
        columnnames = ['id']

my_dwriter = csv.DictWriter(test_csv_2, fieldnames = columnnames)

my_dwriter.writeheader()

my_dwriter.writerow({'id': 'ESD00.074.02'})

test_csv_2 = open('Users\New Owner\Desktop\test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader2:
    print row
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-11-b9d6a6b488af> in <module>()
#       1 import csv
#       2
# ----> 3 f = open('Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')
#       4
#       5 my_csv = csv.reader(f, delimiter = ',')
#
# IOError: [Errno 2] No such file or directory: 'Users\\New Owner\\Desktop\\Public_Art_Data_CSVEdit.csv'

# %%
import csv

f = open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

# %%
import csv

f = open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'w')

for row in my_dreader:
        columnnames = ['id']

my_dwriter = csv.DictWriter(test_csv_2, fieldnames = columnnames)

my_dwriter.writeheader()

my_dwriter.writerow({'id': 'ESD00.074.02'})

test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader2:
    print row
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-13-e3d171a93b4a> in <module>()
#       8     my_dreader = csv.DictReader(f)
#       9
# ---> 10 test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'w')
#      11
#      12 for row in my_dreader:
#
# IOError: [Errno 22] invalid mode ('w') or filename: 'C:\\Users\\New Owner\\Desktop\test_csv_2.csv'

# %%
import csv

f = open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)

for row in my_dreader:
        columnnames = ['id']
        test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'w')

my_dwriter = csv.DictWriter(test_csv_2, fieldnames = columnnames)

my_dwriter.writeheader()

my_dwriter.writerow({'id': 'ESD00.074.02'})

test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader2:
    print row
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a0c96290d4ef> in <module>()
#      12         test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'w')
#      13
# ---> 14 my_dwriter = csv.DictWriter(test_csv_2, fieldnames = columnnames)
#      15
#      16 my_dwriter.writeheader()
#
# NameError: name 'test_csv_2' is not defined

# %%
import csv

f = open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)

for row in my_dreader:
        columnnames = ['id']
        test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'w')
        my_dwriter = csv.DictWriter(test_csv_2, fieldnames = columnnames)
        my_dwriter.writeheader()
        my_dwriter.writerow({'id': 'ESD00.074.02'})

test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader2:
    print row
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-15-053880fa97b3> in <module>()
#      15         my_dwriter.writerow({'id': 'ESD00.074.02'})
#      16
# ---> 17 test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'r')
#      18
#      19 my_dreader_2 = csv.DictReader(test_csv_2)
#
# IOError: [Errno 22] invalid mode ('r') or filename: 'C:\\Users\\New Owner\\Desktop\test_csv_2.csv'

# %%
import csv

f = open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)

columnnames = ['id']

test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'w')

my_dwriter = csv.DictWriter(test_csv_2, fieldnames = columnnames)

my_dwriter.writeheader()

my_dwriter.writerow({'id': 'ESD00.074.02'})

test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader2:
    print row
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-16-845301a2189c> in <module>()
#      10 columnnames = ['id']
#      11
# ---> 12 test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'w')
#      13
#      14 my_dwriter = csv.DictWriter(test_csv_2, fieldnames = columnnames)
#
# IOError: [Errno 22] invalid mode ('w') or filename: 'C:\\Users\\New Owner\\Desktop\test_csv_2.csv'

# %%
import csv

f = open('Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('Users\New Owner\Desktop\test_csv_2.csv', 'r')

for row in my_dreader_2:
    print row

test_csv_loop = open('Users\New Owner\Desktop\test_csv_3.csv', 'w')

fieldnames = ['sac_id']

loop_dwriter = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter.writeheader()

loop_dreader = csv.DictReader(open('Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list []

i = 1
for row in loop_dreader:
    new_dict_list.append({'id': row['sac_id']})
    i =+ 1

loop_dwriter.writerows(new_dict_list)

test_csv_loop.close()

test_csv_loop = open('Users\New Owner\Desktop\test_csv_3.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()
# Out:
#   File "<ipython-input-17-c1258656f91b>", line 25
#     new_dict_list []
#                    ^
# SyntaxError: invalid syntax

# %%
import csv

f = open('Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('Users\New Owner\Desktop\test_csv_2.csv', 'r')

for row in my_dreader_2:
    print row

test_csv_loop = open('Users\New Owner\Desktop\test_csv_3.csv', 'w')

fieldnames = ['sac_id']

loop_dwriter = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter.writeheader()

loop_dreader = csv.DictReader(open('Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list[]

i = 1
for row in loop_dreader:
    new_dict_list.append({'id': row['sac_id']})
    i =+ 1

loop_dwriter.writerows(new_dict_list)

test_csv_loop.close()

test_csv_loop = open('Users\New Owner\Desktop\test_csv_3.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()
# Out:
#   File "<ipython-input-18-a8896e1000a4>", line 25
#     new_dict_list[]
#                   ^
# SyntaxError: invalid syntax

# %%
import csv

f = open('Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('Users\New Owner\Desktop\test_csv_2.csv', 'r')

for row in my_dreader_2:
    print row

test_csv_loop = open('Users\New Owner\Desktop\test_csv_3.csv', 'w')

fieldnames = ['sac_id']

loop_dwriter = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter.writeheader()

loop_dreader = csv.DictReader(open('Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list = []

i = 1
for row in loop_dreader:
    new_dict_list.append({'id': row['sac_id']})
    i =+ 1

loop_dwriter.writerows(new_dict_list)

test_csv_loop.close()

test_csv_loop = open('Users\New Owner\Desktop\test_csv_3.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-19-6e626d8da3c7> in <module>()
#       1 import csv
#       2
# ----> 3 f = open('Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')
#       4
#       5 my_csv = csv.reader(f, delimiter = ',')
#
# IOError: [Errno 2] No such file or directory: 'Users\\New Owner\\Desktop\\Public_Art_Data_CSVEdit.csv'

# %%
import csv

f = open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'r')

for row in my_dreader_2:
    print row

test_csv_loop = open('C:\Users\New Owner\Desktop\test_csv_3.csv', 'w')

fieldnames = ['sac_id']

loop_dwriter = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter.writeheader()

loop_dreader = csv.DictReader(open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list = []

i = 1
for row in loop_dreader:
    new_dict_list.append({'id': row['sac_id']})
    i =+ 1

loop_dwriter.writerows(new_dict_list)

test_csv_loop.close()

test_csv_loop = open('C:\Users\New Owner\Desktop\test_csv_3.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-20-dafb6b4cb750> in <module>()
#       8     my_dreader = csv.DictReader(f)
#       9
# ---> 10 test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'r')
#      11
#      12 for row in my_dreader_2:
#
# IOError: [Errno 22] invalid mode ('r') or filename: 'C:\\Users\\New Owner\\Desktop\test_csv_2.csv'

# %%
import csv

f = open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'r')

for row in my_dreader_2:
    print row

test_csv_loop = open('C:\Users\New Owner\Desktop\test_csv_3.csv', 'w')

fieldnames = ['sac_id']

loop_dwriter = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter.writeheader()

loop_dreader = csv.DictReader(open('C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv'))

new_dict_list = []

i = 1
for row in loop_dreader:
    new_dict_list.append({'id': row['sac_id']})
    i =+ 1

loop_dwriter.writerows(new_dict_list)

test_csv_loop.close()

test_csv_loop = open('C:\Users\New Owner\Desktop\test_csv_3.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-21-e06f2d538cfa> in <module>()
#       8     my_dreader = csv.DictReader(f)
#       9
# ---> 10 test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv', 'r')
#      11
#      12 for row in my_dreader_2:
#
# IOError: [Errno 22] invalid mode ('r') or filename: 'C:\\Users\\New Owner\\Desktop\test_csv_2.csv'

# %%
import csv

f = open(r 'C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open(r 'C:\Users\New Owner\Desktop\test_csv_2.csv')

for row in my_dreader_2:
    print row

test_csv_loop = open('C:\Users\New Owner\Desktop\test_csv_3.csv', 'w')

fieldnames = ['sac_id']

loop_dwriter = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter.writeheader()

loop_dreader = csv.DictReader(open(r 'C:\Users\New Owner\Desktop\Public_Art_Data_CSVEdit.csv'))

new_dict_list = []

i = 1
for row in loop_dreader:
    new_dict_list.append({'id': row['sac_id']})
    i =+ 1

loop_dwriter.writerows(new_dict_list)

test_csv_loop.close()

test_csv_loop = open('C:\Users\New Owner\Desktop\test_csv_3.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-22-b606473ee8b2> in <module>()
#       8     my_dreader = csv.DictReader(f)
#       9
# ---> 10 test_csv_2 = open('C:\Users\New Owner\Desktop\test_csv_2.csv')
#      11
#      12 for row in my_dreader_2:
#
# IOError: [Errno 22] invalid mode ('r') or filename: 'C:\\Users\\New Owner\\Desktop\test_csv_2.csv'

# %%
import csv

f = open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('C:/Users/New Owner/Desktop/test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader_2:
    print row

test_csv_loop = open('C:/Users/New Owner/Desktop/test_csv_3.csv', 'w')

fieldnames = ['sac_id']

loop_dwriter = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter.writeheader()

loop_dreader = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list = []

i = 1
for row in loop_dreader:
    new_dict_list.append({'id': row['sac_id']})
    i =+ 1

loop_dwriter.writerows(new_dict_list)

test_csv_loop.close()

test_csv_loop = open('C:/Users/New Owner/Desktop/test_csv_3.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-17d5c3e1d1d1> in <module>()
#      32     i =+ 1
#      33
# ---> 34 loop_dwriter.writerows(new_dict_list)
#      35
#      36 test_csv_loop.close()
#
# C:\Users\New Owner\AppData\Local\Enthought\Canopy32\App\appdata\canopy-1.7.0.3322.win-x86\lib\csv.pyc in writerows(self, rowdicts)
#     155         rows = []
#     156         for rowdict in rowdicts:
# --> 157             rows.append(self._dict_to_list(rowdict))
#     158         return self.writer.writerows(rows)
#     159
#
# C:\Users\New Owner\AppData\Local\Enthought\Canopy32\App\appdata\canopy-1.7.0.3322.win-x86\lib\csv.pyc in _dict_to_list(self, rowdict)
#     146             if wrong_fields:
#     147                 raise ValueError("dict contains fields not in fieldnames: "
# ...

# %%
import csv

f = open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('C:/Users/New Owner/Desktop/test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader_2:
    print row

test_csv_loop = open('C:/Users/New Owner/Desktop/test_csv_3.csv', 'w')

fieldnames = ['sac_id']

loop_dwriter = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter.writeheader()

loop_dreader = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list = []

i = 1
for row in loop_dreader:
    new_dict_list.append({'sac_id': row['id']})
    i =+ 1

loop_dwriter.writerows(new_dict_list)

test_csv_loop.close()

test_csv_loop = open('C:/Users/New Owner/Desktop/test_csv_3.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-17d5c3e1d1d1> in <module>()
#      32     i =+ 1
#      33
# ---> 34 loop_dwriter.writerows(new_dict_list)
#      35
#      36 test_csv_loop.close()
#
# C:\Users\New Owner\AppData\Local\Enthought\Canopy32\App\appdata\canopy-1.7.0.3322.win-x86\lib\csv.pyc in writerows(self, rowdicts)
#     155         rows = []
#     156         for rowdict in rowdicts:
# --> 157             rows.append(self._dict_to_list(rowdict))
#     158         return self.writer.writerows(rows)
#     159
#
# C:\Users\New Owner\AppData\Local\Enthought\Canopy32\App\appdata\canopy-1.7.0.3322.win-x86\lib\csv.pyc in _dict_to_list(self, rowdict)
#     146             if wrong_fields:
#     147                 raise ValueError("dict contains fields not in fieldnames: "
# ...

# %%
import csv

f = open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('C:/Users/New Owner/Desktop/test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader_2:
    print row

test_csv_loop = open('C:/Users/New Owner/Desktop/test_csv_3.csv', 'w')

fieldnames = ['sac_id']

loop_dwriter = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter.writeheader()

loop_dreader = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list = []

i = 1
for row in loop_dreader:
    new_dict_list.append({'sac_id': row['id']})
    i =+ 1

loop_dwriter.writerows(new_dict_list)

test_csv_loop.close()

test_csv_loop = open('C:/Users/New Owner/Desktop/test_csv_3.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()
# Out:
# {'sac_id': '1'}
# {'sac_id': '2'}
# {'sac_id': '3'}
# {'sac_id': '4'}
# {'sac_id': '5'}
# {'sac_id': '6'}
# {'sac_id': '7'}
# {'sac_id': '8'}
# {'sac_id': '9'}
# {'sac_id': '10'}
# {'sac_id': '11'}
# {'sac_id': '12'}
# {'sac_id': '13'}
# {'sac_id': '14'}
# {'sac_id': '15'}
# {'sac_id': '16'}
# {'sac_id': '17'}
# {'sac_id': '18'}
# {'sac_id': '19'}
# {'sac_id': '20'}
# {'sac_id': '21'}
# {'sac_id': '22'}
# {'sac_id': '23'}
# {'sac_id': '24'}
# {'sac_id': '25'}
# {'sac_id': '26'}
# {'sac_id': '27'}
# {'sac_id': '28'}
# {'sac_id': '29'}
# {'sac_id': '30'}
# {'sac_id': '31'}
# {'sac_id': '32'}
# {'sac_id': '33'}
# {'sac_id': '34'}
# {'sac_id': '35'}
# {'sac_id': '36'}
# {'sac_id': '37'}
# {'sac_id': '38'}
# {'sac_id': '39'}
# {'sac_id': '40'}
# {'sac_id': '41'}
# {'sac_id': '42'}
# {'sac_id': '43'}
# {'sac_id': '44'}
# {'sac_id': '45'}
# {'sac_id': '46'}
# {'sac_id': '47'}
# {'sac_id': '48'}
# {'sac_id': '49'}
# {'sac_id': '50'}
# {'sac_id': '51'}
# {'sac_id': '52'}
# {'sac_id': '53'}
# ...

# %%
import csv

f = open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)
    
test_csv_2 = open('C:/Users/New Owner/Desktop/test_csv_2.csv', 'r')

my_dreader_2 = csv.DictReader(test_csv_2)

for row in my_dreader_2:
    print row

test_csv_loop = open('C:/Users/New Owner/Desktop/test_csv_3.csv', 'w')

fieldnames = ['id']

loop_dwriter = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter.writeheader()

loop_dreader = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list = []

i = 1
for row in loop_dreader:
    new_dict_list.append({'id': row['sac_id']})
    i =+ 1

loop_dwriter.writerows(new_dict_list)

test_csv_loop.close()

test_csv_loop = open('C:/Users/New Owner/Desktop/test_csv_3.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()
# Out:
# {'id': 'ESD00.074.02'}
# {'id': 'CL77.025'}
# {'id': 'CL99.053'}
# {'id': 'PR99.077'}
# {'id': 'CL77.026'}
# {'id': 'CL77.023'}
# {'id': 'CL91.015a,b'}
# {'id': 'PR81.014a-c'}
# {'id': 'GCK74.074'}
# {'id': 'LIB06.011.01-.03'}
# {'id': 'LIB05.002'}
# {'id': 'CL77.015'}
# {'id': 'ESD00.074.06'}
# {'id': 'CETA76.049'}
# {'id': 'GCK00.142.01-.10'}
# {'id': 'PL74.067'}
# {'id': 'PR88.007.01a-g'}
# {'id': 'CL98.050'}
# {'id': 'PR99.044'}
# {'id': 'PR99.043'}
# {'id': 'GCK98.042a-w'}
# {'id': 'PR97.004'}
# {'id': 'WD96.025'}
# {'id': 'PR94.018'}
# {'id': 'SC93.027a-d'}
# {'id': 'CL86.045'}
# {'id': 'CL86.046a-g'}
# {'id': 'PR84.090'}
# {'id': 'CETA79.035a-h'}
# {'id': 'CL77.018'}
# {'id': 'CL75.049'}
# {'id': 'CL75.000'}
# {'id': 'ESD00.074.04'}
# {'id': 'GCK74.045'}
# {'id': 'PR03.050'}
# {'id': 'GCK74.049'}
# {'id': 'ED75.110'}
# {'id': 'PR89.022'}
# {'id': 'LIB06.010'}
# {'id': 'SPU05.053'}
# {'id': 'PR05.054'}
# {'id': 'LIB05.052'}
# {'id': 'LIB05.052'}
# {'id': 'SAC06.001'}
# ...

# %%
import csv

f = open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)

test_csv_loop2 = open('C:/Users/New Owner/Desktop/Public_Art_Data.csv', 'w')

fieldnames2 = ['id', 'project']

loop_dwriter2 = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter2.writeheader()

loop_dreader2 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list2 = []

i = 1
for row in loop_dreader:
    new_dict_list.append({'id': row['sac_id']})
    i =+ 1

loop_dwriter.writerows(new_dict_list)

test_csv_loop.close()

test_csv_loop = open('C:/Users/New Owner/Desktop/Public_Art_Data.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()
# Out:
# {'id': 'ESD00.074.02'}
# {'id': 'CL77.025'}
# {'id': 'CL99.053'}
# {'id': 'PR99.077'}
# {'id': 'CL77.026'}
# {'id': 'CL77.023'}
# {'id': 'CL91.015a,b'}
# {'id': 'PR81.014a-c'}
# {'id': 'GCK74.074'}
# {'id': 'LIB06.011.01-.03'}
# {'id': 'LIB05.002'}
# {'id': 'CL77.015'}
# {'id': 'ESD00.074.06'}
# {'id': 'CETA76.049'}
# {'id': 'GCK00.142.01-.10'}
# {'id': 'PL74.067'}
# {'id': 'PR88.007.01a-g'}
# {'id': 'CL98.050'}
# {'id': 'PR99.044'}
# {'id': 'PR99.043'}
# {'id': 'GCK98.042a-w'}
# {'id': 'PR97.004'}
# {'id': 'WD96.025'}
# {'id': 'PR94.018'}
# {'id': 'SC93.027a-d'}
# {'id': 'CL86.045'}
# {'id': 'CL86.046a-g'}
# {'id': 'PR84.090'}
# {'id': 'CETA79.035a-h'}
# {'id': 'CL77.018'}
# {'id': 'CL75.049'}
# {'id': 'CL75.000'}
# {'id': 'ESD00.074.04'}
# {'id': 'GCK74.045'}
# {'id': 'PR03.050'}
# {'id': 'GCK74.049'}
# {'id': 'ED75.110'}
# {'id': 'PR89.022'}
# {'id': 'LIB06.010'}
# {'id': 'SPU05.053'}
# {'id': 'PR05.054'}
# {'id': 'LIB05.052'}
# {'id': 'LIB05.052'}
# {'id': 'SAC06.001'}
# ...

# %%
test_csv_loop2 = open('C:/Users/New Owner/Desktop/Public_Art_Data.csv', 'w')

fieldnames2 = ['id', 'project']

loop_dwriter2 = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter2.writeheader()

loop_dreader2 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list2 = []

i = 1
for row in loop_dreader2:
    new_dict_list2.append({'id': row['id'], 'project': row['project'']})
    i =+ 1

loop_dwriter2.writerows(new_dict_list2)

test_csv_loop2.close()

test_csv_loop2 = open('C:/Users/New Owner/Desktop/Public_Art_Data.csv')

loop_dreader2 = csv.DictReader(test_csv_loop2)

for i in range (0, 316):
        print loop_dreader2.next()
# Out:
#   File "<ipython-input-31-610bd000bfb8>", line 15
#     new_dict_list2.append({'id': row['id'], 'project': row['project'']})
#                                                                        ^
# SyntaxError: EOL while scanning string literal

# %%
test_csv_loop2 = open('C:/Users/New Owner/Desktop/Public_Art_Data.csv', 'w')

fieldnames2 = ['id', 'project']

loop_dwriter2 = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter2.writeheader()

loop_dreader2 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list2 = []

i = 1
for row in loop_dreader2:
    new_dict_list2.append({'id': row['id'], 'project': row['project']})
    i =+ 1

loop_dwriter2.writerows(new_dict_list2)

test_csv_loop2.close()

test_csv_loop2 = open('C:/Users/New Owner/Desktop/Public_Art_Data.csv')

loop_dreader2 = csv.DictReader(test_csv_loop2)

for i in range (0, 316):
        print loop_dreader2.next()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-32-fe558d0b09bb> in <module>()
#       5 loop_dwriter2 = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)
#       6
# ----> 7 loop_dwriter2.writeheader()
#       8
#       9 loop_dreader2 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))
#
# C:\Users\New Owner\AppData\Local\Enthought\Canopy32\App\appdata\canopy-1.7.0.3322.win-x86\lib\csv.pyc in writeheader(self)
#     139     def writeheader(self):
#     140         header = dict(zip(self.fieldnames, self.fieldnames))
# --> 141         self.writerow(header)
#     142
#     143     def _dict_to_list(self, rowdict):
#
# C:\Users\New Owner\AppData\Local\Enthought\Canopy32\App\appdata\canopy-1.7.0.3322.win-x86\lib\csv.pyc in writerow(self, rowdict)
#     150
#     151     def writerow(self, rowdict):
# ...

# %%
test_csv_loop2 = open('C:/Users/New Owner/Desktop/Project_Location.csv', 'w')

fieldnames2 = ['id', 'project']

loop_dwriter2 = csv.DictWriter(test_csv_loop2, fieldnames2 = fieldnames2)

loop_dwriter2.writeheader()

loop_dreader2 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list2 = []

i = 1
for row in loop_dreader2:
    new_dict_list2.append({'id': row['id'], 'project': row['project']})
    i =+ 1

loop_dwriter2.writerows(new_dict_list2)

test_csv_loop2.close()

test_csv_loop2 = open('C:/Users/New Owner/Desktop/Project_Location.csv')

loop_dreader2 = csv.DictReader(test_csv_loop2)

for i in range (0, 316):
        print loop_dreader2.next()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-e138c1558060> in <module>()
#       3 fieldnames2 = ['id', 'project']
#       4
# ----> 5 loop_dwriter2 = csv.DictWriter(test_csv_loop2, fieldnames2 = fieldnames2)
#       6
#       7 loop_dwriter2.writeheader()
#
# TypeError: __init__() takes at least 3 arguments (2 given)

# %%
test_csv_loop2 = open('C:/Users/New Owner/Desktop/Project_Location.csv', 'w')

fieldnames2 = ['id', 'project']

loop_dwriter2 = csv.DictWriter(test_csv_loop2, fieldnames = fieldnames2)

loop_dwriter2.writeheader()

loop_dreader2 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list2 = []

i = 1
for row in loop_dreader2:
    new_dict_list2.append({'id': row['id'], 'project': row['project']})
    i =+ 1

loop_dwriter2.writerows(new_dict_list2)

test_csv_loop2.close()

test_csv_loop2 = open('C:/Users/New Owner/Desktop/Project_Location.csv')

loop_dreader2 = csv.DictReader(test_csv_loop2)

for i in range (0, 316):
        print loop_dreader2.next()
# Out:
# {'project': 'CENTRAL LIBRARY', 'id': '1'}
# {'project': 'SEATTLE CENTER SCULPTURE GARDEN', 'id': '2'}
# {'project': 'WEST GILMAN BRIDGE', 'id': '3'}
# {'project': 'DOUGLAS-TRUTH BRANCH LIBRARY', 'id': '4'}
# {'project': 'SECOND AVENUE PROJECT', 'id': '5'}
# {'project': 'SEATTLE ARTISTS 1990', 'id': '6'}
# {'project': 'IN PUBLIC: SEATTLE 1991', 'id': '7'}
# {'project': 'JOSE RIZAL PARK', 'id': '8'}
# {'project': 'ALKI BEACH', 'id': '9'}
# {'project': 'LIBRARIES FOR ALL - CENTRAL LIBRARY/LIBRARY UNBOUND', 'id': '10'}
# {'project': 'LIBRARIES FOR ALL--CENTRAL LIBRARY', 'id': '11'}
# {'project': 'I-90 PORTAL', 'id': '12'}
# {'project': 'BALLARD AVENUE', 'id': '13'}
# {'project': '', 'id': '14'}
# {'project': 'FORTSON SQUARE  (Project not complete until 2001)', 'id': '15'}
# {'project': 'CENTRAL LIBRARY', 'id': '16'}
# {'project': 'WESTLAKE PARK', 'id': '17'}
# {'project': 'BENAROYA SYMPHONY HALL', 'id': '18'}
# {'project': 'WEST SEATTLE CULTURAL TRAIL', 'id': '19'}
# ...

# %%
test_csv_loop3 = open('C:/Users/New Owner/Desktop/Date_Made.csv', 'w')

fieldnames3 = ['id', 'date']

loop_dwriter3 = csv.DictWriter(test_csv_loop3, fieldnames = fieldnames3)

loop_dwriter3.writeheader()

loop_dreader3 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list3 = []

i = 1
for row in loop_dreader3:
    new_dict_list3.append({'id': row['id'], 'date': row['date']})
    i =+ 1

loop_dwriter3.writerows(new_dict_list3)

test_csv_loop3.close()

test_csv_loop3 = open('C:/Users/New Owner/Desktop/Date_Made.csv')

loop_dreader3 = csv.DictReader(test_csv_loop3)

for i in range (0, 316):
        print loop_dreader3.next()
# Out:
# {'date': '1957-60', 'id': '1'}
# {'date': '6/23/1999', 'id': '2'}
# {'date': '1991', 'id': '3'}
# {'date': '1979', 'id': '4'}
# {'date': '2/15/2000', 'id': '5'}
# {'date': 'MARCH- JUNE 1994', 'id': '6'}
# {'date': 'JUNE 1991-JANUARY 1992', 'id': '7'}
# {'date': 'FEBRUARY 1978- JUNE 1981', 'id': '8'}
# {'date': 'ca. 1952', 'id': '9'}
# {'date': '2005. 2005, 2006', 'id': '10'}
# {'date': '2003-04', 'id': '11'}
# {'date': '1988', 'id': '12'}
# {'date': '1978', 'id': '13'}
# {'date': '1967', 'id': '14'}
# {'date': '2000-2001', 'id': '15'}
# {'date': '1958-60', 'id': '16'}
# {'date': '1988', 'id': '17'}
# {'date': '1997-98', 'id': '18'}
# {'date': '1997-1998', 'id': '19'}
# {'date': '1997-1998', 'id': '20'}
# {'date': '1997-1998', 'id': '21'}
# {'date': '1996-97', 'id': '22'}
# {'date': '1995-96', 'id': '23'}
# {'date': '1993-94', 'id': '24'}
# {'date': '1992-1993', 'id': '25'}
# {'date': '1985-1986', 'id': '26'}
# {'date': '1983-85', 'id': '27'}
# {'date': '1983-84', 'id': '28'}
# ...

# %%
test_csv_loop4 = open('C:/Users/New Owner/Desktop/Artist_Name.csv', 'w')

fieldnames4 = ['id', 'artist_name']

loop_dwriter4 = csv.DictWriter(test_csv_loop4, fieldnames = fieldnames4)

loop_dwriter4.writeheader()

loop_dreader4 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list4 = []

for row in loop_dreader4:
    new_dict_list4.append({'id': row['id'], 'artist_name': row['artist_name']})

loop_dwriter4.writerows(new_dict_list4)

test_csv_loop4.close()

test_csv_loop4 = open('C:/Users/New Owner/Desktop/Artist_Name.csv')

loop_dreader4 = csv.DictReader(test_csv_loop4)

for i in range (0, 316):
        print loop_dreader4.next()
# Out:
# {'id': '1', 'artist_name': 'George Tsutakawa'}
# {'id': '2', 'artist_name': 'Doris Chase'}
# {'id': '3', 'artist_name': 'Mark Lere'}
# {'id': '4', 'artist_name': 'Richard Spaulding'}
# {'id': '5', 'artist_name': 'Kurt Kiefer'}
# {'id': '6', 'artist_name': ' '}
# {'id': '7', 'artist_name': 'Edgar Hachivi Heap of Birds'}
# {'id': '8', 'artist_name': 'Val Laigo'}
# {'id': '9', 'artist_name': 'Bartoldi After'}
# {'id': '10', 'artist_name': 'Mandy Greer'}
# {'id': '11', 'artist_name': 'Gary Hill'}
# {'id': '12', 'artist_name': 'James Schoppert'}
# {'id': '13', 'artist_name': 'James Jr. Washington'}
# {'id': '14', 'artist_name': 'George Tsutakawa'}
# {'id': '15', 'artist_name': 'Elizabeth Conner'}
# {'id': '16', 'artist_name': 'Ray Jensen'}
# {'id': '17', 'artist_name': 'Robert Maki'}
# {'id': '18', 'artist_name': 'Anna Valentina Murch'}
# {'id': '19', 'artist_name': ' Fels, Donald; Feddersen, Joe; Quick to see Smith, Jaune'}
# ...

# %%
test_csv_loop5 = open('C:/Users/New Owner/Desktop/Art_Piece.csv', 'w')

fieldnames5 = ['id', 'title', 'description', 'media', 'measurements', 'Public_Art_Data_id']

loop_dwriter5 = csv.DictWriter(test_csv_loop5, fieldnames = fieldnames5)

loop_dwriter5.writeheader()

loop_dreader5 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list5 = []

for row in loop_dreader5:
    new_dict_list5.append({'id': row['id'], 'title': row['title'], 'description': row['description'],
    'media': row['media'], 'measurements': row['measurements'], 'Public_Art_Data_id': ''})

loop_dwriter5.writerows(new_dict_list5)

test_csv_loop5.close()

test_csv_loop5 = open('C:/Users/New Owner/Desktop/Art_Piece.csv')

loop_dreader5 = csv.DictReader(test_csv_loop5)

for i in range (0, 316):
        print loop_dreader5.next()
# Out:
# {'description': "''", 'title': 'Fountain of Wisdom', 'media': 'Welded bronze', 'measurements': '', 'Public_Art_Data_id': '', 'id': '1'}
# {'description': "''", 'title': 'Moon Gates', 'media': '', 'measurements': '', 'Public_Art_Data_id': '', 'id': '2'}
# {'description': "''", 'title': 'Seattle Scatter Piece', 'media': 'Concrete, terrazzo', 'measurements': '', 'Public_Art_Data_id': '', 'id': '3'}
# {'description': "''", 'title': 'Renouveau', 'media': 'Stained glass', 'measurements': '', 'Public_Art_Data_id': '', 'id': '4'}
# {'description': "''", 'title': 'Second Avenue Additions', 'media': 'Permanently sited', 'measurements': '', 'Public_Art_Data_id': '', 'id': '5'}
# {'description': "''", 'title': 'Untitled (Kiosk)', 'media': 'Mixed media; wood; metal', 'measurements': '108x45x22"', 'Public_Art_Data_id': '', 'id': '6'}
# ...

# %%
test_csv_loop6 = open('C:/Users/New Owner/Desktop/Direct_Location.csv', 'w')

fieldnames6 = ['id', 'location', 'address', 'latitude', 'longitude','geolocation', 'Public_Art_Data_id']

loop_dwriter6 = csv.DictWriter(test_csv_loop6, fieldnames = fieldnames6)

loop_dwriter6.writeheader()

loop_dreader6 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list6 = []

for row in loop_dreader6:
    new_dict_list6.append({'id': row['id'], 'location': row['location'], 'address': row['address'],
    'latitude': row['latitude'], 'longitude': row['longitude'], 'geolocation': row['geolocation'], 'Public_Art_Data_id': ''})

loop_dwriter6.writerows(new_dict_list6)

test_csv_loop6.close()

test_csv_loop6 = open('C:/Users/New Owner/Desktop/Direct_Location.csv')

loop_dreader6 = csv.DictReader(test_csv_loop5)

for i in range (0, 316):
        print loop_dreader6.next()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-660b8dd71f3e> in <module>()
#      13 for row in loop_dreader6:
#      14     new_dict_list6.append({'id': row['id'], 'location': row['location'], 'address': row['address'],
# ---> 15     'latitude': row['latitude'], 'longitude': row['longitude'], 'geolocation': row['geolocation'], 'Public_Art_Data_id': ''})
#      16
#      17 loop_dwriter6.writerows(new_dict_list6)
#
# KeyError: 'geolocation'

# %%
test_csv_loop6 = open('C:/Users/New Owner/Desktop/Direct_Location.csv', 'w')

fieldnames6 = ['id', 'location', 'address', 'latitude', 'longitude','geolocation', 'Public_Art_Data_id']

loop_dwriter6 = csv.DictWriter(test_csv_loop6, fieldnames = fieldnames6)

loop_dwriter6.writeheader()

loop_dreader6 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list6 = []

for row in loop_dreader6:
    new_dict_list6.append({'id': row['id'], 'location': row['location'], 'address': row['address'],
    'latitude': row['latitude'], 'longitude': row['longitude'], 'geolocation': row['Geolocation'], 'Public_Art_Data_id': ''})

loop_dwriter6.writerows(new_dict_list6)

test_csv_loop6.close()

test_csv_loop6 = open('C:/Users/New Owner/Desktop/Direct_Location.csv')

loop_dreader6 = csv.DictReader(test_csv_loop5)

for i in range (0, 316):
        print loop_dreader6.next()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-44-539b8aeb2a1b> in <module>()
#      24
#      25 for i in range (0, 316):
# ---> 26         print loop_dreader6.next()
#
# C:\Users\New Owner\AppData\Local\Enthought\Canopy32\App\appdata\canopy-1.7.0.3322.win-x86\lib\csv.pyc in next(self)
#     106             # Used only for its side effect.
#     107             self.fieldnames
# --> 108         row = self.reader.next()
#     109         self.line_num = self.reader.line_num
#     110
#
# StopIteration:

# %%
test_csv_loop7 = open('C:/Users/New Owner/Desktop/Art_Classification.csv', 'w')

fieldnames7 = ['id', 'classification', 'Art_Piece_id']

loop_dwriter7 = csv.DictWriter(test_csv_loop6, fieldnames = fieldnames7)

loop_dwriter7.writeheader()

loop_dreader7 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list7 = []

for row in loop_dreader7:
    new_dict_list7.append({'id': row['id'], 'classification': row['classification'], 'Art_Piece_id': ''})

loop_dwriter7.writerows(new_dict_list7)

test_csv_loop7.close()

test_csv_loop7 = open('C:/Users/New Owner/Desktop/Art_Classification.csv')

loop_dreader7 = csv.DictReader(test_csv_loop7)

for i in range (0, 316):
        print loop_dreader7.next()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-47-b222d7a2a521> in <module>()
#       5 loop_dwriter7 = csv.DictWriter(test_csv_loop6, fieldnames = fieldnames7)
#       6
# ----> 7 loop_dwriter7.writeheader()
#       8
#       9 loop_dreader7 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))
#
# C:\Users\New Owner\AppData\Local\Enthought\Canopy32\App\appdata\canopy-1.7.0.3322.win-x86\lib\csv.pyc in writeheader(self)
#     139     def writeheader(self):
#     140         header = dict(zip(self.fieldnames, self.fieldnames))
# --> 141         self.writerow(header)
#     142
#     143     def _dict_to_list(self, rowdict):
#
# C:\Users\New Owner\AppData\Local\Enthought\Canopy32\App\appdata\canopy-1.7.0.3322.win-x86\lib\csv.pyc in writerow(self, rowdict)
#     150
#     151     def writerow(self, rowdict):
# ...

# %%
test_csv_loop7 = open('C:/Users/New Owner/Desktop/Art_Classification.csv', 'w')

fieldnames7 = ['id', 'classification', 'Art_Piece_id']

loop_dwriter7 = csv.DictWriter(test_csv_loop7, fieldnames = fieldnames7)

loop_dwriter7.writeheader()

loop_dreader7 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list7 = []

for row in loop_dreader7:
    new_dict_list7.append({'id': row['id'], 'classification': row['classification'], 'Art_Piece_id': ''})

loop_dwriter7.writerows(new_dict_list7)

test_csv_loop7.close()

test_csv_loop7 = open('C:/Users/New Owner/Desktop/Art_Classification.csv')

loop_dreader7 = csv.DictReader(test_csv_loop7)

for i in range (0, 316):
        print loop_dreader7.next()
# Out:
# {'Art_Piece_id': '', 'id': '1', 'classification': 'Sculpture'}
# {'Art_Piece_id': '', 'id': '2', 'classification': 'Sculpture'}
# {'Art_Piece_id': '', 'id': '3', 'classification': 'Sculpture'}
# {'Art_Piece_id': '', 'id': '4', 'classification': 'Structures'}
# {'Art_Piece_id': '', 'id': '5', 'classification': 'Structures'}
# {'Art_Piece_id': '', 'id': '6', 'classification': 'Sculpture'}
# {'Art_Piece_id': '', 'id': '7', 'classification': 'IN PUBLIC: SEATTLE 1991'}
# {'Art_Piece_id': '', 'id': '8', 'classification': '2-Dimensional'}
# {'Art_Piece_id': '', 'id': '9', 'classification': 'Sculpture'}
# {'Art_Piece_id': '', 'id': '10', 'classification': 'Sculpture'}
# {'Art_Piece_id': '', 'id': '11', 'classification': 'VIDEO Installation'}
# {'Art_Piece_id': '', 'id': '12', 'classification': ''}
# {'Art_Piece_id': '', 'id': '13', 'classification': 'Sculpture'}
# {'Art_Piece_id': '', 'id': '14', 'classification': 'Sculpture'}
# ...

# %%
import csv

f = open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)

test_csv_loop = open('C:/Users/New Owner/Desktop/Public_Art_Data.csv', 'w')

fieldnames = ['id']

loop_dwriter = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter.writeheader()

loop_dreader = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list = []

for row in loop_dreader:
    new_dict_list.append({'id': row['sac_id']})

loop_dwriter.writerows(new_dict_list)

test_csv_loop.close()

test_csv_loop = open('C:/Users/New Owner/Desktop/Public_Art_Data.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()
# Out:
# {'id': 'ESD00.074.02'}
# {'id': 'CL77.025'}
# {'id': 'CL99.053'}
# {'id': 'PR99.077'}
# {'id': 'CL77.026'}
# {'id': 'CL77.023'}
# {'id': 'CL91.015a,b'}
# {'id': 'PR81.014a-c'}
# {'id': 'GCK74.074'}
# {'id': 'LIB06.011.01-.03'}
# {'id': 'LIB05.002'}
# {'id': 'CL77.015'}
# {'id': 'ESD00.074.06'}
# {'id': 'CETA76.049'}
# {'id': 'GCK00.142.01-.10'}
# {'id': 'PL74.067'}
# {'id': 'PR88.007.01a-g'}
# {'id': 'CL98.050'}
# {'id': 'PR99.044'}
# {'id': 'PR99.043'}
# {'id': 'GCK98.042a-w'}
# {'id': 'PR97.004'}
# {'id': 'WD96.025'}
# {'id': 'PR94.018'}
# {'id': 'SC93.027a-d'}
# {'id': 'CL86.045'}
# {'id': 'CL86.046a-g'}
# {'id': 'PR84.090'}
# {'id': 'CETA79.035a-h'}
# {'id': 'CL77.018'}
# {'id': 'CL75.049'}
# {'id': 'CL75.000'}
# {'id': 'ESD00.074.04'}
# {'id': 'GCK74.045'}
# {'id': 'PR03.050'}
# {'id': 'GCK74.049'}
# {'id': 'ED75.110'}
# {'id': 'PR89.022'}
# {'id': 'LIB06.010'}
# {'id': 'SPU05.053'}
# {'id': 'PR05.054'}
# {'id': 'LIB05.052'}
# {'id': 'LIB05.052'}
# {'id': 'SAC06.001'}
# ...

# %%
import csv

f = open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv')

my_csv = csv.reader(f, delimiter = ',')

for row in my_csv:
    my_dreader = csv.DictReader(f)

test_csv_loop = open('C:/Users/New Owner/Desktop/Public_Art_Data.csv', 'w')

fieldnames = ['id']

loop_dwriter = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter.writeheader()

loop_dreader = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list = []

for row in loop_dreader:
    new_dict_list.append({'id': row['sac_id']})

loop_dwriter.writerows(new_dict_list)

test_csv_loop.close()

test_csv_loop = open('C:/Users/New Owner/Desktop/Public_Art_Data.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()
        
# This above code is for the first spreadsheet titled Public_Art_Data

test_csv_loop2 = open('C:/Users/New Owner/Desktop/Project_Location.csv', 'w')

fieldnames2 = ['id', 'project', 'Public_Art_Data_id']

loop_dwriter2 = csv.DictWriter(test_csv_loop2, fieldnames = fieldnames2)

loop_dwriter2.writeheader()

loop_dreader2 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list2 = []

for row in loop_dreader2:
    new_dict_list2.append({'id': row['id'], 'project': row['project'], 'Public_Art_Data_id': ''})

loop_dwriter2.writerows(new_dict_list2)

test_csv_loop2.close()

test_csv_loop2 = open('C:/Users/New Owner/Desktop/Project_Location.csv')

loop_dreader2 = csv.DictReader(test_csv_loop2)

for i in range (0, 316):
        print loop_dreader2.next()

# This above code is for the second spreadsheet titled Project_Location

test_csv_loop3 = open('C:/Users/New Owner/Desktop/Date_Made.csv', 'w')

fieldnames3 = ['id', 'project', 'Public_Art_Data_id']

loop_dwriter3 = csv.DictWriter(test_csv_loop3, fieldnames = fieldnames3)

loop_dwriter3.writeheader()

test_csv_loop3 = open('C:/Users/New Owner/Desktop/Date_Made.csv', 'w')

fieldnames3 = ['id', 'date']

loop_dwriter3 = csv.DictWriter(test_csv_loop3, fieldnames = fieldnames3)

loop_dwriter3.writeheader()

loop_dreader3 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list3 = []

for row in loop_dreader3:
    new_dict_list3.append({'id': row['id'], 'date': row['date'], 'Public_Art_Data_id': ''})

loop_dwriter3.writerows(new_dict_list3)

test_csv_loop3.close()

test_csv_loop3 = open('C:/Users/New Owner/Desktop/Date_Made.csv')

loop_dreader3 = csv.DictReader(test_csv_loop3)

for i in range (0, 316):
    
# This above code is for the third spreadsheet titled Date_Made

test_csv_loop4 = open('C:/Users/New Owner/Desktop/Artist_Name.csv', 'w')

fieldnames4 = ['id', 'artist_name', 'Art_Piece_id']

loop_dwriter4 = csv.DictWriter(test_csv_loop4, fieldnames = fieldnames4)

loop_dwriter4.writeheader()

loop_dreader4 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list4 = []

for row in loop_dreader4:
    new_dict_list4.append({'id': row['id'], 'artist_name': row['artist_name'], 'Art_Piece_id': ''})

loop_dwriter4.writerows(new_dict_list4)

test_csv_loop4.close()

test_csv_loop4 = open('C:/Users/New Owner/Desktop/Artist_Name.csv')

loop_dreader4 = csv.DictReader(test_csv_loop4)

for i in range (0, 316):
        print loop_dreader4.next()
        
#This above code is for the fourth spreadsheet titled Artist_Name

test_csv_loop5 = open('C:/Users/New Owner/Desktop/Art_Piece.csv', 'w')

fieldnames5 = ['id', 'title', 'description', 'media', 'measurements', 'Public_Art_Data_id']

loop_dwriter5 = csv.DictWriter(test_csv_loop5, fieldnames = fieldnames5)

loop_dwriter5.writeheader()

loop_dreader5 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list5 = []

for row in loop_dreader5:
    new_dict_list5.append({'id': row['id'], 'title': row['title'], 'description': row['description'],
    'media': row['media'], 'measurements': row['measurements'], 'Public_Art_Data_id': ''})

loop_dwriter5.writerows(new_dict_list5)

test_csv_loop5.close()

test_csv_loop5 = open('C:/Users/New Owner/Desktop/Art_Piece.csv')

loop_dreader5 = csv.DictReader(test_csv_loop5)

for i in range (0, 316):
        print loop_dreader5.next()

#This above code is for the fifth spreadsheet titled Art_Piece

test_csv_loop6 = open('C:/Users/New Owner/Desktop/Direct_Location.csv', 'w')

fieldnames6 = ['id', 'location', 'address', 'latitude', 'longitude','Geolocation', 'Public_Art_Data_id']

loop_dwriter6 = csv.DictWriter(test_csv_loop6, fieldnames = fieldnames6)

loop_dwriter6.writeheader()

loop_dreader6 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list6 = []

for row in loop_dreader6:
    new_dict_list6.append({'id': row['id'], 'location': row['location'], 'address': row['address'],
    'latitude': row['latitude'], 'longitude': row['longitude'], 'Geolocation': row['Geolocation'], 'Public_Art_Data_id': ''})

loop_dwriter6.writerows(new_dict_list6)

test_csv_loop6.close()

test_csv_loop6 = open('C:/Users/New Owner/Desktop/Direct_Location.csv')

loop_dreader6 = csv.DictReader(test_csv_loop6)

for i in range (0, 316):
        print loop_dreader6.next()

# This above code is for the sixth spreadsheet titled Direct_Location

test_csv_loop7 = open('C:/Users/New Owner/Desktop/Art_Classification.csv', 'w')

fieldnames7 = ['id', 'classification', 'Art_Piece_id']

loop_dwriter7 = csv.DictWriter(test_csv_loop7, fieldnames = fieldnames7)

loop_dwriter7.writeheader()

loop_dreader7 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list7 = []

for row in loop_dreader7:
    new_dict_list7.append({'id': row['id'], 'classification': row['classification'], 'Art_Piece_id': ''})

loop_dwriter7.writerows(new_dict_list7)

test_csv_loop7.close()

test_csv_loop7 = open('C:/Users/New Owner/Desktop/Art_Classification.csv')

loop_dreader7 = csv.DictReader(test_csv_loop7)

for i in range (0, 316):
        print loop_dreader7.next()

# This above code is for the seventh spreadsheet titled Art_Classification
# Out:
#   File "<ipython-input-50-823c22eec319>", line 101
#     test_csv_loop4 = open('C:/Users/New Owner/Desktop/Artist_Name.csv', 'w')
#                  ^
# IndentationError: expected an indented block

# %%
import csv

f = open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv')

# This part imports the csv module and connects us to the correct pathname for the original table

test_csv_loop = open('C:/Users/New Owner/Desktop/Public_Art_Data.csv', 'w')

fieldnames = ['id']

loop_dwriter = csv.DictWriter(test_csv_loop, fieldnames = fieldnames)

loop_dwriter.writeheader()

# This part allows us to create a loop so we can write the data in multiple times starting with the headers 
loop_dreader = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list = []

for row in loop_dreader:
    new_dict_list.append({'id': row['sac_id']})

loop_dwriter.writerows(new_dict_list)

# Here I created a dictionary list to append the data into the new table I've created

test_csv_loop.close()

test_csv_loop = open('C:/Users/New Owner/Desktop/Public_Art_Data.csv')

loop_dreader = csv.DictReader(test_csv_loop)

for i in range (0, 316):
        print loop_dreader.next()

#This loop allows me to do it for every entry within the original table
        
# This above code is for the first spreadsheet titled Public_Art_Data
# Out:
# {'id': 'ESD00.074.02'}
# {'id': 'CL77.025'}
# {'id': 'CL99.053'}
# {'id': 'PR99.077'}
# {'id': 'CL77.026'}
# {'id': 'CL77.023'}
# {'id': 'CL91.015a,b'}
# {'id': 'PR81.014a-c'}
# {'id': 'GCK74.074'}
# {'id': 'LIB06.011.01-.03'}
# {'id': 'LIB05.002'}
# {'id': 'CL77.015'}
# {'id': 'ESD00.074.06'}
# {'id': 'CETA76.049'}
# {'id': 'GCK00.142.01-.10'}
# {'id': 'PL74.067'}
# {'id': 'PR88.007.01a-g'}
# {'id': 'CL98.050'}
# {'id': 'PR99.044'}
# {'id': 'PR99.043'}
# {'id': 'GCK98.042a-w'}
# {'id': 'PR97.004'}
# {'id': 'WD96.025'}
# {'id': 'PR94.018'}
# {'id': 'SC93.027a-d'}
# {'id': 'CL86.045'}
# {'id': 'CL86.046a-g'}
# {'id': 'PR84.090'}
# {'id': 'CETA79.035a-h'}
# {'id': 'CL77.018'}
# {'id': 'CL75.049'}
# {'id': 'CL75.000'}
# {'id': 'ESD00.074.04'}
# {'id': 'GCK74.045'}
# {'id': 'PR03.050'}
# {'id': 'GCK74.049'}
# {'id': 'ED75.110'}
# {'id': 'PR89.022'}
# {'id': 'LIB06.010'}
# {'id': 'SPU05.053'}
# {'id': 'PR05.054'}
# {'id': 'LIB05.052'}
# {'id': 'LIB05.052'}
# {'id': 'SAC06.001'}
# ...

# %%
test_csv_loop2 = open('C:/Users/New Owner/Desktop/Project_Location.csv', 'w')

fieldnames2 = ['id', 'project', 'Public_Art_Data_id']

loop_dwriter2 = csv.DictWriter(test_csv_loop2, fieldnames = fieldnames2)

loop_dwriter2.writeheader()

loop_dreader2 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list2 = []

for row in loop_dreader2:
    new_dict_list2.append({'id': row['id'], 'project': row['project'], 'Public_Art_Data_id': ''})

loop_dwriter2.writerows(new_dict_list2)

test_csv_loop2.close()

test_csv_loop2 = open('C:/Users/New Owner/Desktop/Project_Location.csv')

loop_dreader2 = csv.DictReader(test_csv_loop2)

for i in range (0, 316):
        print loop_dreader2.next()

# This above code is for the second spreadsheet titled Project_Location
# Out:
# {'project': 'CENTRAL LIBRARY', 'Public_Art_Data_id': '', 'id': '1'}
# {'project': 'SEATTLE CENTER SCULPTURE GARDEN', 'Public_Art_Data_id': '', 'id': '2'}
# {'project': 'WEST GILMAN BRIDGE', 'Public_Art_Data_id': '', 'id': '3'}
# {'project': 'DOUGLAS-TRUTH BRANCH LIBRARY', 'Public_Art_Data_id': '', 'id': '4'}
# {'project': 'SECOND AVENUE PROJECT', 'Public_Art_Data_id': '', 'id': '5'}
# {'project': 'SEATTLE ARTISTS 1990', 'Public_Art_Data_id': '', 'id': '6'}
# {'project': 'IN PUBLIC: SEATTLE 1991', 'Public_Art_Data_id': '', 'id': '7'}
# {'project': 'JOSE RIZAL PARK', 'Public_Art_Data_id': '', 'id': '8'}
# {'project': 'ALKI BEACH', 'Public_Art_Data_id': '', 'id': '9'}
# {'project': 'LIBRARIES FOR ALL - CENTRAL LIBRARY/LIBRARY UNBOUND', 'Public_Art_Data_id': '', 'id': '10'}
# {'project': 'LIBRARIES FOR ALL--CENTRAL LIBRARY', 'Public_Art_Data_id': '', 'id': '11'}
# {'project': 'I-90 PORTAL', 'Public_Art_Data_id': '', 'id': '12'}
# ...

# %%
test_csv_loop3 = open('C:/Users/New Owner/Desktop/Date_Made.csv', 'w')

fieldnames3 = ['id', 'date', 'Public_Art_Data_id']

loop_dwriter3 = csv.DictWriter(test_csv_loop3, fieldnames = fieldnames3)

loop_dwriter3.writeheader()

loop_dreader3 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list3 = []

for row in loop_dreader3:
    new_dict_list3.append({'id': row['id'], 'date': row['date'], 'Public_Art_Data_id': ''})

loop_dwriter3.writerows(new_dict_list3)

test_csv_loop3.close()

test_csv_loop3 = open('C:/Users/New Owner/Desktop/Date_Made.csv')

loop_dreader3 = csv.DictReader(test_csv_loop3)

for i in range (0, 316):
        print loop_dreader3.next()
        
# This above code is for the third spreadsheet titled Date_Made
# Out:
# {'date': '1957-60', 'Public_Art_Data_id': '', 'id': '1'}
# {'date': '6/23/1999', 'Public_Art_Data_id': '', 'id': '2'}
# {'date': '1991', 'Public_Art_Data_id': '', 'id': '3'}
# {'date': '1979', 'Public_Art_Data_id': '', 'id': '4'}
# {'date': '2/15/2000', 'Public_Art_Data_id': '', 'id': '5'}
# {'date': 'MARCH- JUNE 1994', 'Public_Art_Data_id': '', 'id': '6'}
# {'date': 'JUNE 1991-JANUARY 1992', 'Public_Art_Data_id': '', 'id': '7'}
# {'date': 'FEBRUARY 1978- JUNE 1981', 'Public_Art_Data_id': '', 'id': '8'}
# {'date': 'ca. 1952', 'Public_Art_Data_id': '', 'id': '9'}
# {'date': '2005. 2005, 2006', 'Public_Art_Data_id': '', 'id': '10'}
# {'date': '2003-04', 'Public_Art_Data_id': '', 'id': '11'}
# {'date': '1988', 'Public_Art_Data_id': '', 'id': '12'}
# {'date': '1978', 'Public_Art_Data_id': '', 'id': '13'}
# {'date': '1967', 'Public_Art_Data_id': '', 'id': '14'}
# {'date': '2000-2001', 'Public_Art_Data_id': '', 'id': '15'}
# {'date': '1958-60', 'Public_Art_Data_id': '', 'id': '16'}
# ...

# %%
test_csv_loop4 = open('C:/Users/New Owner/Desktop/Artist_Name.csv', 'w')

fieldnames4 = ['id', 'artist_name', 'Art_Piece_id']

loop_dwriter4 = csv.DictWriter(test_csv_loop4, fieldnames = fieldnames4)

loop_dwriter4.writeheader()

loop_dreader4 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list4 = []

for row in loop_dreader4:
    new_dict_list4.append({'id': row['id'], 'artist_name': row['artist_name'], 'Art_Piece_id': ''})

loop_dwriter4.writerows(new_dict_list4)

test_csv_loop4.close()

test_csv_loop4 = open('C:/Users/New Owner/Desktop/Artist_Name.csv')

loop_dreader4 = csv.DictReader(test_csv_loop4)

for i in range (0, 316):
        print loop_dreader4.next()

# This above code is for the fourth spreadsheet titled Artist_Name
# Out:
# {'Art_Piece_id': '', 'id': '1', 'artist_name': 'George Tsutakawa'}
# {'Art_Piece_id': '', 'id': '2', 'artist_name': 'Doris Chase'}
# {'Art_Piece_id': '', 'id': '3', 'artist_name': 'Mark Lere'}
# {'Art_Piece_id': '', 'id': '4', 'artist_name': 'Richard Spaulding'}
# {'Art_Piece_id': '', 'id': '5', 'artist_name': 'Kurt Kiefer'}
# {'Art_Piece_id': '', 'id': '6', 'artist_name': ' '}
# {'Art_Piece_id': '', 'id': '7', 'artist_name': 'Edgar Hachivi Heap of Birds'}
# {'Art_Piece_id': '', 'id': '8', 'artist_name': 'Val Laigo'}
# {'Art_Piece_id': '', 'id': '9', 'artist_name': 'Bartoldi After'}
# {'Art_Piece_id': '', 'id': '10', 'artist_name': 'Mandy Greer'}
# {'Art_Piece_id': '', 'id': '11', 'artist_name': 'Gary Hill'}
# {'Art_Piece_id': '', 'id': '12', 'artist_name': 'James Schoppert'}
# {'Art_Piece_id': '', 'id': '13', 'artist_name': 'James Jr. Washington'}
# {'Art_Piece_id': '', 'id': '14', 'artist_name': 'George Tsutakawa'}
# ...

# %%
test_csv_loop5 = open('C:/Users/New Owner/Desktop/Art_Piece.csv', 'w')

fieldnames5 = ['id', 'title', 'description', 'media', 'measurements', 'Public_Art_Data_id']

loop_dwriter5 = csv.DictWriter(test_csv_loop5, fieldnames = fieldnames5)

loop_dwriter5.writeheader()

loop_dreader5 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list5 = []

for row in loop_dreader5:
    new_dict_list5.append({'id': row['id'], 'title': row['title'], 'description': row['description'],
    'media': row['media'], 'measurements': row['measurements'], 'Public_Art_Data_id': ''})

loop_dwriter5.writerows(new_dict_list5)

test_csv_loop5.close()

test_csv_loop5 = open('C:/Users/New Owner/Desktop/Art_Piece.csv')

loop_dreader5 = csv.DictReader(test_csv_loop5)

for i in range (0, 316):
        print loop_dreader5.next()

# This above code is for the fifth spreadsheet titled Art_Piece

test_csv_loop6 = open('C:/Users/New Owner/Desktop/Direct_Location.csv', 'w')

fieldnames6 = ['id', 'location', 'address', 'latitude', 'longitude','Geolocation', 'Public_Art_Data_id']

loop_dwriter6 = csv.DictWriter(test_csv_loop6, fieldnames = fieldnames6)

loop_dwriter6.writeheader()

loop_dreader6 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list6 = []

for row in loop_dreader6:
    new_dict_list6.append({'id': row['id'], 'location': row['location'], 'address': row['address'],
    'latitude': row['latitude'], 'longitude': row['longitude'], 'Geolocation': row['Geolocation'], 'Public_Art_Data_id': ''})

loop_dwriter6.writerows(new_dict_list6)

test_csv_loop6.close()

test_csv_loop6 = open('C:/Users/New Owner/Desktop/Direct_Location.csv')

loop_dreader6 = csv.DictReader(test_csv_loop6)

for i in range (0, 316):
        print loop_dreader6.next()
        
# This above code is for the sixth spreadsheet titled Direct_Location

test_csv_loop7 = open('C:/Users/New Owner/Desktop/Art_Classification.csv', 'w')

fieldnames7 = ['id', 'classification', 'Art_Piece_id']

loop_dwriter7 = csv.DictWriter(test_csv_loop7, fieldnames = fieldnames7)

loop_dwriter7.writeheader()

loop_dreader7 = csv.DictReader(open('C:/Users/New Owner/Desktop/Public_Art_Data_CSVEdit.csv', 'r'))

new_dict_list7 = []

for row in loop_dreader7:
    new_dict_list7.append({'id': row['id'], 'classification': row['classification'], 'Art_Piece_id': ''})

loop_dwriter7.writerows(new_dict_list7)

test_csv_loop7.close()

test_csv_loop7 = open('C:/Users/New Owner/Desktop/Art_Classification.csv')

loop_dreader7 = csv.DictReader(test_csv_loop7)

for i in range (0, 316):
        print loop_dreader7.next()
        
# This above code is for the seventh and final spreadsheet titled Art_Classification
# Out:
# {'description': "''", 'title': 'Fountain of Wisdom', 'media': 'Welded bronze', 'measurements': '', 'Public_Art_Data_id': '', 'id': '1'}
# {'description': "''", 'title': 'Moon Gates', 'media': '', 'measurements': '', 'Public_Art_Data_id': '', 'id': '2'}
# {'description': "''", 'title': 'Seattle Scatter Piece', 'media': 'Concrete, terrazzo', 'measurements': '', 'Public_Art_Data_id': '', 'id': '3'}
# {'description': "''", 'title': 'Renouveau', 'media': 'Stained glass', 'measurements': '', 'Public_Art_Data_id': '', 'id': '4'}
# {'description': "''", 'title': 'Second Avenue Additions', 'media': 'Permanently sited', 'measurements': '', 'Public_Art_Data_id': '', 'id': '5'}
# {'description': "''", 'title': 'Untitled (Kiosk)', 'media': 'Mixed media; wood; metal', 'measurements': '108x45x22"', 'Public_Art_Data_id': '', 'id': '6'}
# ...
