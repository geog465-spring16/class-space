# %%
import sys

# %%
sys.path.append('C:\Python27\ArcGIS10.3\Lib\site-packages')

# %%
import pg
from pg import DB

# %%
db = DB(dbname = 'geog465_tal10', host='geog-db2.geog.uw.edu', port=5432, user='tal10', 
        passwd = 'tal10')

# %%
# Stores the Parks_Features table in a variable
query = db.query('select * from parks_features')

# %%
# Tests whether table is empty
query.dictresult()
# Out:
# [{'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 3, 'parks_id': 53},
#  {'feature_id': 4, 'parks_id': 1083},
# ...

# %%
import csv

# %%
f = open(r'U:\Geog 465\Lab 2\parks_features_copy.csv', 'w') # Stores reference to file for new table

# %%
columnlist = ['feature_id', 'parks_id'] # Stores column names

# %%
# Connects column names to file
writer = csv.DictWriter(f, fieldnames = columnlist)

# %%
# Writes column names to file
writer.writeheader()

# %%
# Writes table to file
writer.writerows(query.dictresult())

# %%
f.close()

# %%
f = open(r'U:\Geog 465\Lab 2\parks_features_copy.csv') # Stores reference to updated file

# %%
# Tests that file was updated succesfully
reader = csv.DictReader(f)
for row in reader: 
    print row
# Out:
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# {'feature_id': '3', 'parks_id': '53'}
# ...
