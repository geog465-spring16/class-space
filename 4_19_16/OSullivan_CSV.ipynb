# %%
import csv

# %%
file = open('Z:\GEOG 465\Seattle_Parks_Features.csv')

# %%
my_csv = csv.reader(file, delimiter = ',')

# %%
for row in my_csv:
    print row[1]
# Out:
# Name
# 12th and Howe Play Park
# 12th Ave S Viewpoint
# 14th Ave NW Boat Ramp
# 14th Ave NW Boat Ramp
# 14th Ave NW Boat Ramp
# 32nd Ave W Boat Launch
# 6th Ave NW Pocket Park
# A. B. Ernst Park
# A. B. Ernst Park
# Adams Street Boat Ramp
# Adams Street Boat Ramp
# Albert Davis Park
# Alki Beach Park
# Alki Beach Park
# Alki Beach Park
# Alki Beach Park
# Alki Beach Park
# Alki Beach Park
# Alki Beach Park
# Alki Beach Park
# Alki Beach Park
# Alki Beach Park
# Alki Beach Park
# Alki Playground
# Alki Playground
# Belvoir Place
# Alki Playground
# Alki Playground
# Alki Playground
# Alki Playground
# Alki Playground
# Alki Playground
# Alki Playground
# Alki Playground
# Alki Playground
# Alvin Larkins Park
# Amy Yee Tennis Center
# Amy Yee Tennis Center
# Amy Yee Tennis Center
# Amy Yee Tennis Center
# Amy Yee Tennis Center
# Amy Yee Tennis Center
# Andover Place
# Andover Place
# Arroyos Natural Area
# Arroyos Natural Area
# Atlantic City Boat Ramp
# Atlantic City Boat Ramp
# ...

# %%
my_dreader = csv.DictReader(file)

# %%
for row in my_dreader:
    print row

# %%
test_csv_1 = open('/Users/kieranos/Desktop/test_csv_1.csv', 'w')

# %%
columnnames = ['Name', 'Alt_Name', 'xPos', 'yPos', 'hours', 'Feature_Desc', 'YOUTH_ONLY', 'LIGHTING' 'Location 1']

# %%
my_dwriter = csv.DictWriter(test_csv_1, fieldnames = columnnames)

# %%
my_dwriter.writeheader()

# %%
my_dwriter.writeheader({'Name': 'Alki Beach Park', 'Atl_Name': 'Luna Park', 'xPos': '-122.402', 'yPos': '47.582', 'hours':'11am - 11 pm','Feature_Desc': 'Beach','YOUTH_ONLY': 'FALSE','LIGHTING': 'FALSE','Location 1': '1702 Alki Ave SW'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-79341be138cc> in <module>()
# ----> 1 my_dwriter.writeheader({'Name': 'Alki Beach Park', 'Atl_Name': 'Luna Park', 'xPos': '-122.402', 'yPos': '47.582', 'hours':'11am - 11 pm','Feature_Desc': 'Beach','YOUTH_ONLY': 'FALSE','LIGHTING': 'FALSE','Location 1': '1702 Alki Ave SW'})
#
# TypeError: writeheader() takes exactly 1 argument (2 given)

# %%
test_csv_2.close()

# %%
test_csv_2 = open('Z:\GEOG 465\test_csv_2.csv', 'r')

# %%
my_dreader_2 = csv.DictReader(test_csv_2)

# %%
for row in my_dreader_2:
    print row
