# %%
import csv

my_file = open('C:\Users\Travis\Downloads\Building_Permits___Current.csv')

# %%
my_dreader = csv.DictReader(my_file)

# %%
for row in my_dreader:
    print row
# Out:
# {'Category': 'MULTIFAMILY', 'Status': 'Permit Issued', 'Description': 'Construct interior alterations to existing townhouse (den conversion to bedroom), and enlarge exterior window opening, subject to field inspection (STFI).', 'Master Use Permit': '', 'Application Date': '04/18/2016', 'Location': '(47.57885517, -122.31487587)', 'Value': '$15000.00', 'Expiration Date': '10/18/2017', 'Permit Type': 'Construction', 'Action Type': 'ADD/ALT', 'Issue Date': '04/18/2016', 'Longitude': '-122.31487587', 'Address': '2721 14TH AVE S', 'Latitude': '47.57885517', 'Application/Permit Number': '6529938', 'Contractor': '', 'Work Type': 'No plan review', 'Applicant Name': 'KENNEDY, SIMON', 'Final Date': '', 'Permit and Complaint Status URL': 'http://web6.seattle.gov/dpd/PermitStatus/Project.aspx?id=6529938'}
# ...

# %%
new_file = open('C:\Users\Travis\Downloads\NewTable_travis_smith.csv', 'w')

# %%
columnnames = ['id', 'PERMIT_TYPE', 'CATEGORY', 'APPLICANT_NAME', 'STATUS']

# %%
my_dwriter = csv.DictWriter(new_file, fieldnames = columnnames)

# %%
my_dwriter.writeheader()

# %%
my_dwriter.writerow({'id': 6529938
, 'PERMIT_TYPE': 'Construction', 'CATEGORY': 'MULTIFAMILY', 'APPLICANT_NAME': 'Kennedy, Simon', 'STATUS': 'Permit Issued'})

# %%
my_dwriter.writerow({'id': 6493214
, 'PERMIT_TYPE': 'Site Development', 'CATEGORY': 'SINGLE FAMILY', 'APPLICANT_NAME': 'Millhollin, William', 'STATUS': 'AP Closed'})

# %%
my_dwriter.writerow({'id': 6529721
, 'PERMIT_TYPE': 'Demolition', 'CATEGORY': 'SINGLE FAMILY', 'APPLICANT_NAME': 'O\'Leary, Kevin', 'STATUS': 'Reviews Completed'})

# %%
new_file.close()

# %%
new_file = open('C:\Users\Travis\Downloads\NewTable.csv', 'r')

# %%
my_dreader_two = csv.DictReader(new_file)

# %%
for row in my_dreader_two:
    print row
# Out:
# {'CATEGORY': 'MULTIFAMILY', 'STATUS': 'Permit Issued', 'id': '6529938', 'APPLICANT_NAME': 'Kennedy, Simon', 'PERMIT_TYPE': 'Construction'}
# {'CATEGORY': 'SINGLE FAMILY', 'STATUS': 'AP Closed', 'id': '6493214', 'APPLICANT_NAME': 'Millhollin, William', 'PERMIT_TYPE': 'Site Development'}
# {'CATEGORY': 'SINGLE FAMILY', 'STATUS': 'Reviews Completed', 'id': '6529721', 'APPLICANT_NAME': "O'Leary, Kevin", 'PERMIT_TYPE': 'Demolition'}
