# %% [markdown]
# Bethany Yollin
# Hyun Lee

# %%
import csv

# %%
f = 'C:\\Users\\Bethany\\Downloads\\table.csv'

# %%
with open(f) as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        print(row['Open'], row['Close'])
# Out:
# ('55.490002', '56.459999')
# ('55.299999', '55.650002')
# ('55.220001', '55.360001')
# ('55.119999', '55.349998')
# ('54.369999', '54.650002')
# ('54.490002', '54.310001')
# ('54.669998', '54.419998')
# ('54.869999', '54.459999')
# ('54.360001', '55.119999')
# ('55.189999', '54.560001')
# ('55.43', '55.43')
# ('55.049999', '55.57')
# ('54.950001', '55.23')
# ('54.93', '55.049999')
# ('53.66', '54.709999')
# ('54.209999', '53.540001')
# ('53.84', '54.209999')
# ('54.110001', '53.970001')
# ('53.610001', '54.07')
# ('53.25', '53.860001')
# ('54.919998', '53.490002')
# ('54.209999', '54.66')
# ('53.450001', '54.349998')
# ('52.75', '53.59')
# ('52.709999', '53.169998')
# ('53', '53.07')
# ('52.93', '52.049999')
# ('51.889999', '52.84')
# ('50.799999', '51.650002')
# ('51.560001', '51.029999')
# ('52.400002', '52.029999')
# ('52.970001', '52.349998')
# ('52.41', '52.950001')
# ('50.970001', '52.580002')
# ('51.349998', '50.880001')
# ('52.599998', '51.299999')
# ('51.73', '52.099998')
# ...

# %%
with open('C:\\rProjects\\465-class-space\\4_19_16\\Lee_Yollin\\OpenClose.csv', 'w') as csvfile:
    fieldnames = ['Open', 'Close']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerow({'Open':'55.490002', 'Close': '56.459999'})
    writer.writerow({'Open': '55.299999', 'Close': '55.650002'})
    writer.writerow({'Open': '55.220001', 'Close': '55.360001'})
